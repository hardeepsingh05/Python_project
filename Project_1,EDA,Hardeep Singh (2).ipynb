# %% [markdown]
# # Project as Exploratory Data Analysis (EDA) by HARDEEP SINGH

# %% [markdown]
# # Overview

# %%
#  Understanding how EDA is done in 'Python' using the 'Jupyter'
#  Various baisc and simple steps involved in the Exploratory Data Analysis (EDA)
#  Performing Exploratory Data Analysis (EDA) on a given dataset related to Car_Sales

# %% [markdown]
# # Contents

# %%
# 1. Importing the essential Python Libraries 

# 2. Loading the Dataset related to Car_Sales

# 3. Pattern of the given Data

# 4. Handling of Duplicates

# 5. Handling of Outliers

# 6. Handle Missing Values

# 7. Univariate Analysis

# 8. Bivariate Analysis

# 9. Multivariate Analysis

# %% [markdown]
# # 1. Importing the essential Python Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 2. Loading the Dataset related to Car_Sales

# %%
# Loading the Dataset related to Car_Sales using Pandas
data = pd.read_csv('car_sales.csv')

# %%
# Calling the above created variable of data
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# # 3. Pattern of the given Data

# %%
# Displaying First Ten Data Observations
data.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
# Displaying Last Ten Data Observations
data.tail(10)
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 147   Volkswagen  Passat              51.102               16.725
# 148   Volkswagen  Cabrio               9.569               16.575
# 149   Volkswagen     GTI               5.596               13.760
# 150   Volkswagen  Beetle              49.463                  NaN
# 151        Volvo     S40              16.957                  NaN
# 152        Volvo     V40               3.545                  NaN
# 153        Volvo     S70              15.245                  NaN
# 154        Volvo     V70              17.531                  NaN
# 155        Volvo     C70               3.493                  NaN
# 156        Volvo     S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 147    Passenger               21.20          1.8       150.0      106.4
# 148    Passenger               19.99          2.0       115.0       97.4
# ...

# %%
# Displaying the Number of Variables and Observations
data.shape
# Out:
# (157, 16)

# %%
# So in this dataset (data), there are 157 Rows and 16 Columns

# %%
data.dtypes
# It will display the Variables Names and their Data Types
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
# Counting the number of Non-Missing Values for each Variable
data.count()
# Out:
# Manufacturer           157
# Model                  157
# Sales_in_thousands     157
# __year_resale_value    121
# Vehicle_type           157
# Price_in_thousands     155
# Engine_size            156
# Horsepower             156
# Wheelbase              156
# Width                  156
# Length                 156
# Curb_weight            155
# Fuel_capacity          156
# Fuel_efficiency        154
# Latest_Launch          157
# Power_perf_factor      155
# dtype: int64

# %%
data.describe()
# It will give statistical information of all numerical features in our dataset
# Count - count of the values
# mean - average of the values
# std - standard deviation
# min - minimum values as compared to the other values
# 25% - first quartile
# 50% - second quartile of near to the median
# 75% - third quartile
# max - maximum values as compared to the other values
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
# We can also check this distribution for a particular numeric column
data.Sales_in_thousands.describe()
# Out:
# count    157.000000
# mean      52.998076
# std       68.029422
# min        0.110000
# 25%       14.114000
# 50%       29.450000
# 75%       67.956000
# max      540.561000
# Name: Sales_in_thousands, dtype: float64

# %%
data.describe(include='all')
# In this way, we can check for the all the attributes of the Dataset
# Out:
#        Manufacturer Model  Sales_in_thousands  __year_resale_value  \
# count           157   157          157.000000           121.000000
# unique           30   156                 NaN                  NaN
# top           Dodge  Neon                 NaN                  NaN
# freq             11     2                 NaN                  NaN
# mean            NaN   NaN           52.998076            18.072975
# std             NaN   NaN           68.029422            11.453384
# min             NaN   NaN            0.110000             5.160000
# 25%             NaN   NaN           14.114000            11.260000
# 50%             NaN   NaN           29.450000            14.180000
# 75%             NaN   NaN           67.956000            19.875000
# max             NaN   NaN          540.561000            67.550000
#
#        Vehicle_type  Price_in_thousands  Engine_size  Horsepower   Wheelbase  \
# count           157          155.000000   156.000000  156.000000  156.000000
# ...

# %%
# For checking the complete summary of the Dataset which will include data types,shape and memory storage, attributes, their counts
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %% [markdown]
# # 4. Handling of Duplicates

# %%
data.duplicated()
# It will show the list of duplicated values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
data.drop_duplicates()
# Now, those values if exists would have been dropped
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# Here in this dataset, we do not have any duplicates as checked above but if we had then by using the below syntax, we can remove them 
# data.drop_duplicates(subset='Column_name',inplace=False)

# %% [markdown]
# # 5. Handling of Outliers

# %%
e0=data.Engine_size.min()
e100=data.Engine_size.max()
q1=data.Engine_size.quantile(0.25)
q2=data.Engine_size.quantile(0.5)
q3=data.Engine_size.quantile(0.75)
IQR=q3-q1
# IQR - Inter Quartile Range
# q1 - First_quartile
# q2 - Second_quatile
# q3 - Third_quartile

# %%
lf = q1 - 1.5*IQR
# lc - lower_fence
uf = q3 + 1.5*IQR
# uf - upper_fence

# %%
lf
# Out:
# 0.3874999999999993

# %%
uf
# Out:
# 5.487500000000001

# %%
# If lf<e0 then there are NO Outliers on the lower side
# If uf>e100 then there are NO Outliers on the higher side

# %%
print( "e0 = " , e0 ,", e100 = " , e100 ,", lf = " , lf ,", uf = " , uf)
# Out:
# e0 =  1.0 , e100 =  8.0 , lf =  0.3874999999999993 , uf =  5.487500000000001

# %%
# Let's check the outliers in 'Engine_size' of this Dataset using Boxplot
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x="Engine_size")
plt.show()

# %%
data.Engine_size.clip(upper=uf)
# Out:
# 0      1.8
# 1      3.2
# 2      3.2
# 3      3.5
# 4      1.8
#       ...
# 152    1.9
# 153    2.4
# 154    2.4
# 155    2.3
# 156    2.9
# Name: Engine_size, Length: 157, dtype: float64

# %%
data.Engine_size.clip(upper=uf,inplace=True)
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x="Engine_size")
plt.show()
# So, In this we can see that the outliers are dropped out of the dataset and new Min and Max values have been assigned

# %% [markdown]
# # 6. Handle Missing Values

# %%
# Detecting the Missing Values
data.__year_resale_value=pd.to_numeric(data.__year_resale_value,errors='coerce')
data.isnull().sum()
# Dataset.isnull.sum() will give the number of missing values in the dataset
# error='coerce' will replace the non-numeric values with NaN
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
# Missing Values in the Dataset 
# __year_resale_value = 36
# Fuel_efficieny = 3
# all other attributes also have some of the missing values

data.dropna(how='any',inplace=True)
# After this all the missing values are dropped from the dataset

# %%
data.isnull().sum()
# Here we can check that all the null value counts are zero
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %% [markdown]
# # 7. Univariate Analysis (Taking only one attribute out of Data)

# %%
plt.figure(figsize=(23,10))
sns.countplot(x=data['Manufacturer'],palette='Paired')
plt.show()
# CountPlot will basically display the count of number of the cars made by the Manufacturer

# %%
# Engine type is measured in Litres(1l to 8l)
plt.figure(figsize=(23,8))
sns.countplot(x=data['Engine_size'],palette='Paired')
plt.show()

# %%
plt.figure(figsize=(24,10))
sns.countplot(x='Manufacturer',data=data)
plt.show()
# This plot is showing a lot of cars of different Manufacterers below with their respective count

# %% [markdown]
# # 8. Bivariate Analysis (Taking only two attribute out of Data)

# %%
# Scatter Plot of 'Engine_size' verse 'Price_of_the_Vehicles'
plt.figure(figsize=(15,8))
sns.scatterplot(data=data,x="Engine_size",y='Price_in_thousands')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=data,x='Engine_size',y='Horsepower')
plt.show()
#This barplot is showing 'Horsepower' verse 'Engine_size' of the cars

# %%
plt.figure(figsize=(25,10))
sns.lineplot(
    data=data, x="Manufacturer", y="Fuel_efficiency", err_style="bars", ci=68
)
plt.show()

# So in this lineplot, we will the 'fuel_efficiency' verse 'Manufacturer' in 'bars' style mode with 'confidence_interval(ci) = 68'

# %%
# In above lineplot we can see that high fuel_efficiency is give by 'Saturn' cars and unfortunately this car company has been discontinued.
# After that 'Chevrolet' cars are performing good and after that 'Hyundai' 
# These bars are telling about the 'fuel_efficiency' range of each car manufacturer.

# %%
sns.displot(data=data, x="Wheelbase", hue="Vehicle_type", multiple="stack")
# Here actually we are trying to make a distplot using Seaborn after giving the 'Vehicle_type' for a bit of colored visualization

# %% [markdown]
# # 9. Multivariate Analysis (Taking multiple attribute out of Data)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=data,x='Horsepower',y='Fuel_efficiency',palette='bright',hue='Vehicle_type',style='Vehicle_type')
plt.show()
# This scatterplot is showing the visualization between the different attributes of the given Data with 'Vehicle_type' as colored

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=data,x='Engine_size',y='Fuel_efficiency',hue='Vehicle_type')
plt.show()
# Here a Bar plot with three attributes have been visualized to the in bound relations between them.

# %%
sns.pairplot(data=data, vars=['Sales_in_thousands','__year_resale_value','Price_in_thousands'],hue='Vehicle_type')
# In this pairplot, we can actually see a mixer of different plots such as Density (KDE) plot, Scatterplot,histogram etc
